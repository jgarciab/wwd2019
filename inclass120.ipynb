# %%
##Some code to run at the beginning of the file, to be able to show images in the notebook
##Don't worry about this cell

#Print the plots in this screen
# %matplotlib inline 

#Be able to plot images saved in the hard drive
from IPython.display import Image 

#Make the notebook wider
from IPython.core.display import display, HTML 
display(HTML("<style>.container { width:90% !important; }</style>"))

import seaborn as sns
import pylab as plt
import pandas as pd
import numpy as np
import scipy.stats

import statsmodels.formula.api as smf
# Out:
# <style>.container { width:90% !important; }</style>
# /opt/anaconda/anaconda3/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/anaconda/anaconda3/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def qq_plot(x):
    (osm, osr),(slope, intercept, r)  = scipy.stats.probplot(x, dist='norm', plot=None)
    plt.plot(osm, osr, '.', osm, slope*osm + intercept)
    plt.xlabel('Quantiles',fontsize=14)
    plt.ylabel('Quantiles Obs',fontsize=14)

# %%
#salary for Assistant Professors, Associate Professors and Professors in a college in the U.S.
# !head data/salary.csv
# Out:
# "","rank","discipline","yrs.since.phd","yrs.service","sex","salary"
# "1","Prof","B",19,18,"Male",139750
# "2","Prof","B",20,16,"Male",173200
# "3","AsstProf","B",4,3,"Male",79750
# "4","Prof","B",45,39,"Male",115000
# "5","Prof","B",40,41,"Male",141500
# "6","AssocProf","B",6,6,"Male",97000
# "7","Prof","B",30,23,"Male",175000
# "8","Prof","B",45,45,"Male",147765
# "9","Prof","B",21,20,"Male",119250

# %%
#Read the data
salary = pd.read_csv("data/salary.csv",index_col=0)
salary.columns = ["rank","discipline","years_since_phd","years_service","sex","salary"]
salary.head()
# Out:
#        rank discipline  years_since_phd  years_service   sex  salary
# 1      Prof          B               19             18  Male  139750
# 2      Prof          B               20             16  Male  173200
# 3  AsstProf          B                4              3  Male   79750
# 4      Prof          B               45             39  Male  115000
# 5      Prof          B               40             41  Male  141500

# %%
##histogram and qq plot, and transform salary if needed. 
#Normality is not an assumption, but makes things easier

# %%
#Pairplot or heatmap to decide on the variables (avoid multicolinearity)

# %%
#Run a regression using as many variables as you can without multicolinearity problems

# %%
#Look at the fittedvalues vs residual plot

# %%
#Do this plot and interpret
salary["predicted"] = res.fittedvalues
sns.lmplot(x="salary",y="predicted",hue="sex",col="discipline",row="rank",data=salary,truncate=True)
