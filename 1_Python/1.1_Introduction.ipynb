# %%
from IPython.display import Image 
from IPython.core.display import display, HTML 
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ## Working with Data 2019
# ` Javier Garcia-Bernardo (garcia@uva.nl)`
#
#
#
# **Office hours:**
# - This week: Thursday 3-5pm (so you have time to try on your own)
# - Every other week: Wednesday 9-11am

# %% [markdown]
# ### WWD: Objective
# *Provide with the tools needed in quantitative research.*
# - download, clean and merge databases.
# - explore their data using visualizations.
# - *understand* and carry basic statistical tests.
#
# → Learn how to code

# %% [markdown]
# ### WWD: Coding
# - Simpler and faster than manually/Excel (once you learn)
# - Required if "big data"
# - Useful tools: Beautiful graphs, merging data, missing data imputation
# - Quick access to new tools: e.g. Network analysis, data scraping
# - **Replicability**: Exact recipe
#
# → Frustrating to learn

# %%
#source: https://www.r-bloggers.com/data-science-in-businesscomputational-social-science-in-academia/
Image("./images/ccsvenn.jpeg",width=500)

# %% [markdown]
# ### WWD: Python
# - Syntax is easier than R
# - Debugging in R is painful
# - Community is more active than in R
# - It's _much_ better for text analysis
# - It's better for machine learning
# - Easy to switch to other languages from Python.

# %%
#source https://www.economist.com/science-and-technology/2018/07/19/python-has-brought-computer-programming-to-a-vast-new-audience
Image("./images/python.png",width=500)

# %% [markdown]
# ## Grades
# - Attendance/participation (5% of the grade)
# - Assignments (50% of the grade):
#     - Deadlines: January 9th, 18th, 23rd, 29th
#     - Start early, it's easy to get stuck.
#     - Submission: Collected automatically from the server
# - Research design draft (10% of the grade):
#     - Deadline: January 15th
#     - Submission through Canvas
# - Execution of the research design (35% of the grade):
#     - Deadline: February 1st
#     - Submission through Canvas
#
# ## Late assignments:
# - Penalized with 10% off each day.
# - No assignment can be re-taken.
# - Extensions are not granted except in cases of emergency (or collective bargaining).

# %% [markdown]
# ## Classes:
# - 90 minutes lecture
# - 30 minutes break+practice
# - *ASK IF YOU HAVE QUESTIONS*
#
#
# ## Collaboration:
# - Encouraged, but with limits:
#   - Two students may not hand in the same code (plagiarism).
#   - Code adapted from online sources should be acknowledged: e.g. `Code adapted from user <user>: <link>`
# - Happy hour: Wednesday 9-11am (except this week: Thursday 3-5pm)
#
# ## Useful links
# - Server: http://corpnet.uva.nl/classroom
# - Stackoverflow: http://stackoverflow.com/
# - Collaborative cheatsheet: https://docs.google.com/document/d/1CPDjsn3Zz71JA0RW_I-2DS8l_sj1-OTjIwFMBmK5l6s/edit
# - Email: garcia@uva.nl

# %%
Image("./images/plan.jpg")
